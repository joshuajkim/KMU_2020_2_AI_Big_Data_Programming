# %%
import pandas as pd
import numpy as np

# %%
fruit = pd.read_csv('data/fruit.csv')
fruit
# Out:
#      State  Apple  Orange  Banana
# 0    Texas     12      10      40
# 1  Arizona      9       7      12
# 2  Florida      0      14     190

# %% [markdown]
# ## Stack <-> (Unstack)

# %%
fruit = fruit.set_index('State')
fruit
# Out:
#          Apple  Orange  Banana
# State
# Texas       12      10      40
# Arizona      9       7      12
# Florida      0      14     190

# %%
fruit_tidy = fruit.stack().reset_index(drop=False)
fruit_tidy
# Out:
#      State level_1    0
# 0    Texas   Apple   12
# 1    Texas  Orange   10
# 2    Texas  Banana   40
# 3  Arizona   Apple    9
# 4  Arizona  Orange    7
# 5  Arizona  Banana   12
# 6  Florida   Apple    0
# 7  Florida  Orange   14
# 8  Florida  Banana  190

# %%
fruit_tidy.columns = ['State', 'fruit', 'weight']
fruit_tidy
# Out:
#      State   fruit  weight
# 0    Texas   Apple      12
# 1    Texas  Orange      10
# 2    Texas  Banana      40
# 3  Arizona   Apple       9
# 4  Arizona  Orange       7
# 5  Arizona  Banana      12
# 6  Florida   Apple       0
# 7  Florida  Orange      14
# 8  Florida  Banana     190

# %% [markdown]
# ## Melt <-> (Pivot)

# %%
fruit = pd.read_csv('data/fruit.csv')
fruit = fruit.set_index('State')
fruit = fruit.reset_index()
fruit
# Out:
#      State  Apple  Orange  Banana
# 0    Texas     12      10      40
# 1  Arizona      9       7      12
# 2  Florida      0      14     190

# %%
fruit.melt(id_vars='State',
           value_vars=['Apple', 'Orange', 'Banana'],
           var_name='fruit',
           value_name='weight')
# Out:
#      State   fruit  weight
# 0    Texas   Apple      12
# 1  Arizona   Apple       9
# 2  Florida   Apple       0
# 3    Texas  Orange      10
# 4  Arizona  Orange       7
# 5  Florida  Orange      14
# 6    Texas  Banana      40
# 7  Arizona  Banana      12
# 8  Florida  Banana     190

# %% [markdown]
# ## Unstack / Pivot

# %%
fruit.set_index('State').stack()
# Out:
# State
# Texas    Apple      12
#          Orange     10
#          Banana     40
# Arizona  Apple       9
#          Orange      7
#          Banana     12
# Florida  Apple       0
#          Orange     14
#          Banana    190
# dtype: int64

# %%
# unstack changes the every datapoint on the last index column to the new column name! (by default)
fruit.set_index('State').stack().unstack()
# Out:
#          Apple  Orange  Banana
# State
# Texas       12      10      40
# Arizona      9       7      12
# Florida      0      14     190

# %%
# But if you wanna unstack with the datapoints on the first index column, then try this!
fruit.set_index('State').stack().unstack(0)
# Out:
# State   Texas  Arizona  Florida
# Apple      12        9        0
# Orange     10        7       14
# Banana     40       12      190

# %%
fruit_tidy.pivot(index='State',
                 columns='fruit',
                 values='weight')
# Out:
# fruit    Apple  Banana  Orange
# State
# Arizona      9      12       7
# Florida      0     190      14
# Texas       12      40      10

# %% [markdown]
# ## Example

# %%
flights = pd.read_csv('data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
agg = flights.groupby(['AIRLINE', 'WEEKDAY'])['CANCELLED'].mean()
agg
# Out:
# AIRLINE  WEEKDAY
# AA       1          0.032106
#          2          0.007341
#          3          0.011949
#          4          0.015004
#          5          0.014151
#                       ...
# WN       3          0.014118
#          4          0.007911
#          5          0.005828
#          6          0.010132
#          7          0.006066
# Name: CANCELLED, Length: 98, dtype: float64

# %%
agg.unstack()
# Out:
# WEEKDAY         1         2         3         4         5         6         7
# AIRLINE
# AA       0.032106  0.007341  0.011949  0.015004  0.014151  0.018667  0.021837
# AS       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B6       0.000000  0.012658  0.000000  0.000000  0.000000  0.000000  0.000000
# DL       0.006068  0.005208  0.005131  0.001940  0.001982  0.003195  0.001294
# EV       0.034130  0.023918  0.022910  0.026895  0.013111  0.022504  0.030233
# F9       0.016129  0.005376  0.000000  0.000000  0.005155  0.011050  0.015625
# HA       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# MQ       0.086785  0.032819  0.025145  0.039146  0.028000  0.038356  0.055777
# NK       0.035354  0.013158  0.013953  0.013216  0.012821  0.019900  0.009390
# OO       0.030581  0.011156  0.014478  0.013627  0.026399  0.024125  0.031385
# UA       0.018914  0.017498  0.007799  0.007719  0.010195  0.006682  0.013487
# US       0.026906  0.018018  0.004545  0.003953  0.009050  0.004695  0.022814
# VX       0.007194  0.000000  0.000000  0.014184  0.006667  0.000000  0.014815
# WN       0.012708  0.019562  0.014118  0.007911  0.005828  0.010132  0.006066

# %%
agg.unstack(0)
# Out:
# AIRLINE        AA   AS        B6        DL        EV        F9   HA        MQ  \
# WEEKDAY
# 1        0.032106  0.0  0.000000  0.006068  0.034130  0.016129  0.0  0.086785
# 2        0.007341  0.0  0.012658  0.005208  0.023918  0.005376  0.0  0.032819
# 3        0.011949  0.0  0.000000  0.005131  0.022910  0.000000  0.0  0.025145
# 4        0.015004  0.0  0.000000  0.001940  0.026895  0.000000  0.0  0.039146
# 5        0.014151  0.0  0.000000  0.001982  0.013111  0.005155  0.0  0.028000
# 6        0.018667  0.0  0.000000  0.003195  0.022504  0.011050  0.0  0.038356
# 7        0.021837  0.0  0.000000  0.001294  0.030233  0.015625  0.0  0.055777
#
# AIRLINE        NK        OO        UA        US        VX        WN
# WEEKDAY
# 1        0.035354  0.030581  0.018914  0.026906  0.007194  0.012708
# 2        0.013158  0.011156  0.017498  0.018018  0.000000  0.019562
# 3        0.013953  0.014478  0.007799  0.004545  0.000000  0.014118
# 4        0.013216  0.013627  0.007719  0.003953  0.014184  0.007911
# 5        0.012821  0.026399  0.010195  0.009050  0.006667  0.005828
# 6        0.019900  0.024125  0.006682  0.004695  0.000000  0.010132
# 7        0.009390  0.031385  0.013487  0.022814  0.014815  0.006066

# %% [markdown]
# ## Pivot Table

# %%
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
pd.pivot_table(data=flights,
               index='AIRLINE',
               columns='WEEKDAY',
               values='CANCELLED',
               aggfunc='mean',
               fill_value=0)
# Out:
# WEEKDAY         1         2         3         4         5         6         7
# AIRLINE
# AA       0.032106  0.007341  0.011949  0.015004  0.014151  0.018667  0.021837
# AS       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B6       0.000000  0.012658  0.000000  0.000000  0.000000  0.000000  0.000000
# DL       0.006068  0.005208  0.005131  0.001940  0.001982  0.003195  0.001294
# EV       0.034130  0.023918  0.022910  0.026895  0.013111  0.022504  0.030233
# F9       0.016129  0.005376  0.000000  0.000000  0.005155  0.011050  0.015625
# HA       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# MQ       0.086785  0.032819  0.025145  0.039146  0.028000  0.038356  0.055777
# NK       0.035354  0.013158  0.013953  0.013216  0.012821  0.019900  0.009390
# OO       0.030581  0.011156  0.014478  0.013627  0.026399  0.024125  0.031385
# UA       0.018914  0.017498  0.007799  0.007719  0.010195  0.006682  0.013487
# US       0.026906  0.018018  0.004545  0.003953  0.009050  0.004695  0.022814
# VX       0.007194  0.000000  0.000000  0.014184  0.006667  0.000000  0.014815
# WN       0.012708  0.019562  0.014118  0.007911  0.005828  0.010132  0.006066
