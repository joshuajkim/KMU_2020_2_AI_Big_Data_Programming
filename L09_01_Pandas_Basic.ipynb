# %%
# The fundamental objects in pandas are: Dictionary or Numpy Array!

# %%
import pandas as pd
import numpy as np

# %%
# Read a CSV file!
movie_df = pd.read_csv('data/movie.csv') # Relative Path!
movie_df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
# Pandas DataFrame: Columns + Indices + Values

# %%
# See all the columns in movie_df
movie_df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
# See all the indices in movie_df
movie_df.index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
# See all the values in movie_df (Numpy Array formatted!)
movie_df.values
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
# See it's Numpy Array?
type(movie_df.values)
# Out:
# numpy.ndarray

# %%
# Read an Excel file!
stock_df = pd.read_excel('data/stocks.xlsx')
stock_df.head()
# Out:
#   Symbol  Shares  Low  High
# 0   AAPL      80   95   110
# 1   TSLA      50   80   130
# 2    WMT      40   55    70

# %%
# Read all the sheets in an Excel file! (sheet_name)
stock_df = pd.read_excel('data/stocks.xlsx', sheet_name=['stock2016', 'stock2017', 'stock2018'])
stock_df['stock2016'].head()
# Out:
#   Symbol  Shares  Low  High
# 0   AAPL      80   95   110
# 1   TSLA      50   80   130
# 2    WMT      40   55    70

# %%
# Incase that an Excel file has thousands of sheets, type 'None' to read all the sheets!
stock_df = pd.read_excel('data/stocks.xlsx', sheet_name=None)
stock_df['stock2016'].head()
# Out:
#   Symbol  Shares  Low  High
# 0   AAPL      80   95   110
# 1   TSLA      50   80   130
# 2    WMT      40   55    70

# %%
stock2016_df, stock2017_df, stock2018_df = stock_df.values()

# %%
stock2016_df.head()
# Out:
#   Symbol  Shares  Low  High
# 0   AAPL      80   95   110
# 1   TSLA      50   80   130
# 2    WMT      40   55    70

# %%
# Save it to csv (to_excel is not recommended because it often returns an error!)
movie_df.to_csv('data/movie2.csv')
# Save it to csv without indices
movie_df.to_csv('data/movie2.csv', index=False)

# %%
# See dtypes!
movie_df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
# See all the info of movie_df!
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
# Each Column in DataFrame is called "Series"!

# %%
# movie_df['director_name'] OR movie_df.director_name

# %%
director_name = movie_df['director_name']
duration = movie_df['duration']

# %%
# DataFrame & Series Method (1): head / tail

# %%
movie_df.head(3)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
# 2  Color      Sam Mendes                   602.0     148.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# ...

# %%
director_name.head(2)
# Out:
# 0     James Cameron
# 1    Gore Verbinski
# Name: director_name, dtype: object

# %%
director_name.tail(3)
# Out:
# 4913    Benjamin Roberds
# 4914         Daniel Hsia
# 4915            Jon Gunn
# Name: director_name, dtype: object

# %%
# DataFrame & Series Method (2): value_counts
    # value_counts also outputs a Series! (remember this for the later contents!)

# %%
director_name.value_counts()
# Out:
# Steven Spielberg       26
# Woody Allen            22
# Clint Eastwood         20
# Martin Scorsese        20
# Spike Lee              16
#                        ..
# Richard Marquand        1
# Michel Hazanavicius     1
# Pedro Almodóvar         1
# Nick Hamm               1
# Scott Kalvert           1
# Name: director_name, Length: 2397, dtype: int64

# %%
# value_counts() is only applied to Series, NOT dataframe!
movie_df.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-e56dde5906da> in <module>
#       1 # value_counts() is only applied to Series, NOT dataframe!
# ----> 2 movie_df.value_counts()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
# normalize can make percentages!
director_name.value_counts(normalize=True)
# Out:
# Steven Spielberg       0.005401
# Woody Allen            0.004570
# Clint Eastwood         0.004155
# Martin Scorsese        0.004155
# Spike Lee              0.003324
#                          ...
# Richard Marquand       0.000208
# Michel Hazanavicius    0.000208
# Pedro Almodóvar        0.000208
# Nick Hamm              0.000208
# Scott Kalvert          0.000208
# Name: director_name, Length: 2397, dtype: float64

# %%
# DataFrame & Series Method (3): size
    # size outputs the total number of data including "NaN Values"!

# %%
director_name.size
# Out:
# 4916

# %%
# for Dataframe, size outputs the total number of data all across the rows and columns!
movie_df.size
# Out:
# 137648

# %%
# DataFrame & Series Method (4): shape

# %%
duration.shape
# Out:
# (4916,)

# %%
movie_df.shape
# Out:
# (4916, 28)

# %%
movie_df.shape[0] # number of rows
# Out:
# 4916

# %%
movie_df.shape[1] # number of columns
# Out:
# 28

# %%
# DataFrame & Series Method (5): len
    # calculates only number of "Rows"!

# %%
len(duration)
# Out:
# 4916

# %%
len(movie_df)
# Out:
# 4916

# %%
# DataFrame & Series Method (6): count
    # outputs the total number of data excluding "NaN Values"!

# %%
movie_df.count()
# Out:
# color                        4897
# director_name                4814
# num_critic_for_reviews       4867
# duration                     4901
# director_facebook_likes      4814
# actor_3_facebook_likes       4893
# actor_2_name                 4903
# actor_1_facebook_likes       4909
# gross                        4054
# genres                       4916
# actor_1_name                 4909
# movie_title                  4916
# num_voted_users              4916
# cast_total_facebook_likes    4916
# actor_3_name                 4893
# facenumber_in_poster         4903
# plot_keywords                4764
# movie_imdb_link              4916
# num_user_for_reviews         4895
# language                     4904
# country                      4911
# content_rating               4616
# budget                       4432
# title_year                   4810
# actor_2_facebook_likes       4903
# imdb_score                   4916
# aspect_ratio                 4590
# ...

# %%
# DataFrame & Series Method (7): min, max
    # Only applied to Numeric values!
    # If a string-type column has no NaN Values, it outputs the shortest string values (min)!

# %%
duration.min()
# Out:
# 7.0

# %%
duration.max()
# Out:
# 511.0

# %%
movie_df.min()
# Out:
# num_critic_for_reviews                                                       1
# duration                                                                     7
# director_facebook_likes                                                      0
# actor_3_facebook_likes                                                       0
# actor_1_facebook_likes                                                       0
# gross                                                                      162
# genres                                                                  Action
# movie_title                                                            #Horror
# num_voted_users                                                              5
# cast_total_facebook_likes                                                    0
# facenumber_in_poster                                                         0
# movie_imdb_link              http://www.imdb.com/title/tt0006864/?ref_=fn_t...
# ...

# %%
# DataFrame & Series Method (8): mean, median, std, sum
    # applied only to numeric values!
    # make averages WITHOUT NaN Values!

# %%
duration.mean()
# Out:
# 107.0907977963681

# %%
movie_df.mean()
# Out:
# num_critic_for_reviews       1.379889e+02
# duration                     1.070908e+02
# director_facebook_likes      6.910145e+02
# actor_3_facebook_likes       6.312763e+02
# actor_1_facebook_likes       6.494488e+03
# gross                        4.764451e+07
# num_voted_users              8.264492e+04
# cast_total_facebook_likes    9.579816e+03
# facenumber_in_poster         1.377320e+00
# num_user_for_reviews         2.676688e+02
# budget                       3.654749e+07
# title_year                   2.002448e+03
# actor_2_facebook_likes       1.621924e+03
# imdb_score                   6.437429e+00
# aspect_ratio                 2.222349e+00
# movie_facebook_likes         7.348294e+03
# dtype: float64

# %%
duration.median()
# Out:
# 103.0

# %%
movie_df.median()
# Out:
# num_critic_for_reviews            108.00
# duration                          103.00
# director_facebook_likes            48.00
# actor_3_facebook_likes            366.00
# actor_1_facebook_likes            982.00
# gross                        25043962.00
# num_voted_users                 33132.50
# cast_total_facebook_likes        3049.00
# facenumber_in_poster                1.00
# num_user_for_reviews              153.00
# budget                       19850000.00
# title_year                       2005.00
# actor_2_facebook_likes            593.00
# imdb_score                          6.60
# aspect_ratio                        2.35
# movie_facebook_likes              159.00
# dtype: float64

# %%
duration.std()
# Out:
# 25.28601531289993

# %%
movie_df.std()
# Out:
# num_critic_for_reviews       1.202394e+02
# duration                     2.528602e+01
# director_facebook_likes      2.832954e+03
# actor_3_facebook_likes       1.625875e+03
# actor_1_facebook_likes       1.510699e+04
# gross                        6.737255e+07
# num_voted_users              1.383222e+05
# cast_total_facebook_likes    1.816432e+04
# facenumber_in_poster         2.023826e+00
# num_user_for_reviews         3.729348e+02
# budget                       1.002427e+08
# title_year                   1.245398e+01
# actor_2_facebook_likes       4.011300e+03
# imdb_score                   1.127802e+00
# aspect_ratio                 1.402940e+00
# movie_facebook_likes         1.920602e+04
# dtype: float64

# %%
duration.sum()
# Out:
# 524852.0

# %%
# In this case, all the strings are concatenated altogether!
movie_df.sum()
# Out:
# num_critic_for_reviews                                                  671592
# duration                                                                524852
# director_facebook_likes                                            3.32654e+06
# actor_3_facebook_likes                                             3.08884e+06
# actor_1_facebook_likes                                             3.18814e+07
# gross                                                              1.93151e+11
# genres                       Action|Adventure|Fantasy|Sci-FiAction|Adventur...
# movie_title                  AvatarPirates of the Caribbean: At World's End...
# num_voted_users                                                      406282451
# cast_total_facebook_likes                                             47094375
# facenumber_in_poster                                                      6753
# movie_imdb_link              http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# ...

# %%
# DataFrame & Series Method (9): describe

# %%
# describe in numeric data
duration.describe()
# Out:
# count    4901.000000
# mean      107.090798
# std        25.286015
# min         7.000000
# 25%        93.000000
# 50%       103.000000
# 75%       118.000000
# max       511.000000
# Name: duration, dtype: float64

# %%
# describe in string data
director_name.describe()
# Out:
# count                 4814
# unique                2397
# top       Steven Spielberg
# freq                    26
# Name: director_name, dtype: object

# %%
# but in dataframe, only numeric data can be applied!
movie_df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
# For your convenience, it looks so much better!
movie_df.describe().T
# Out:
#                             count          mean           std      min  \
# num_critic_for_reviews     4867.0  1.379889e+02  1.202394e+02     1.00
# duration                   4901.0  1.070908e+02  2.528602e+01     7.00
# director_facebook_likes    4814.0  6.910145e+02  2.832954e+03     0.00
# actor_3_facebook_likes     4893.0  6.312763e+02  1.625875e+03     0.00
# actor_1_facebook_likes     4909.0  6.494488e+03  1.510699e+04     0.00
# gross                      4054.0  4.764451e+07  6.737255e+07   162.00
# num_voted_users            4916.0  8.264492e+04  1.383222e+05     5.00
# cast_total_facebook_likes  4916.0  9.579816e+03  1.816432e+04     0.00
# facenumber_in_poster       4903.0  1.377320e+00  2.023826e+00     0.00
# num_user_for_reviews       4895.0  2.676688e+02  3.729348e+02     1.00
# budget                     4432.0  3.654749e+07  1.002427e+08   218.00
# title_year                 4810.0  2.002448e+03  1.245398e+01  1916.00
# ...

# %%
# DataFrame & Series Method (10): quantile

# %%
duration.quantile(0.25)
# Out:
# 93.0

# %%
duration.quantile(0.75)
# Out:
# 118.0

# %%
movie_df.quantile(0.75)
# Out:
# num_critic_for_reviews            191.00
# duration                          118.00
# director_facebook_likes           189.75
# actor_3_facebook_likes            633.00
# actor_1_facebook_likes          11000.00
# gross                        61108412.75
# num_voted_users                 93772.75
# cast_total_facebook_likes       13616.75
# facenumber_in_poster                2.00
# num_user_for_reviews              320.50
# budget                       43000000.00
# title_year                       2011.00
# actor_2_facebook_likes            912.00
# imdb_score                          7.20
# aspect_ratio                        2.35
# movie_facebook_likes             2000.00
# Name: 0.75, dtype: float64

# %%
# DataFrame & Series Method (11): isnull

# %%
director_name.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
movie_df.isnull()
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     False          False                   False     False
# 1     False          False                   False     False
# 2     False          False                   False     False
# 3     False          False                   False     False
# 4      True          False                    True      True
# ...     ...            ...                     ...       ...
# 4911  False          False                   False     False
# 4912  False           True                   False     False
# 4913  False          False                   False     False
# 4914  False          False                   False     False
# 4915  False          False                   False     False
#
#       director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                       False                   False         False
# 1                       False                   False         False
# ...

# %%
# Total number of Nan values
movie_df.isnull().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
# percentage of NaN values
(movie_df.isnull().mean() * 100).round(2).astype('str') + ' %'
# Out:
# color                         0.39 %
# director_name                 2.07 %
# num_critic_for_reviews         1.0 %
# duration                      0.31 %
# director_facebook_likes       2.07 %
# actor_3_facebook_likes        0.47 %
# actor_2_name                  0.26 %
# actor_1_facebook_likes        0.14 %
# gross                        17.53 %
# genres                         0.0 %
# actor_1_name                  0.14 %
# movie_title                    0.0 %
# num_voted_users                0.0 %
# cast_total_facebook_likes      0.0 %
# actor_3_name                  0.47 %
# facenumber_in_poster          0.26 %
# plot_keywords                 3.09 %
# movie_imdb_link                0.0 %
# num_user_for_reviews          0.43 %
# language                      0.24 %
# country                        0.1 %
# content_rating                 6.1 %
# budget                        9.85 %
# title_year                    2.16 %
# actor_2_facebook_likes        0.26 %
# ...

# %%
# Total number of NaN values all across the columns
movie_df.isnull().sum().sum()
# Out:
# 2654

# %%
# DataFrame & Series Method (12): dropna, fillna

# %%
movie_df.dropna()
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 4899  Color    Olivier Assayas                    81.0     110.0
# 4900  Color       Jafar Panahi                    64.0      90.0
# 4906  Color      Shane Carruth                   143.0      77.0
# 4908  Color   Robert Rodriguez                    56.0      81.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
movie_df.fillna('Joshua is Happy!')
# Out:
#                  color      director_name num_critic_for_reviews  \
# 0                Color      James Cameron                    723
# 1                Color     Gore Verbinski                    302
# 2                Color         Sam Mendes                    602
# 3                Color  Christopher Nolan                    813
# 4     Joshua is Happy!        Doug Walker       Joshua is Happy!
# ...                ...                ...                    ...
# 4911             Color        Scott Smith                      1
# 4912             Color   Joshua is Happy!                     43
# 4913             Color   Benjamin Roberds                     13
# 4914             Color        Daniel Hsia                     14
# 4915             Color           Jon Gunn                     43
#
#               duration director_facebook_likes actor_3_facebook_likes  \
# 0                  178                       0                    855
# ...

# %%
# Because of a few NaN values, all the other integers are returned as Floats!
# You can re-type them as integer only after dropna or fillna has been done!
duration.fillna(0).astype('int')
# Out:
# 0       178
# 1       169
# 2       148
# 3       164
# 4         0
#        ...
# 4911     87
# 4912     43
# 4913     76
# 4914    100
# 4915     90
# Name: duration, Length: 4916, dtype: int32

# %%
# broadcasting is all the same as Numpy Array!
duration + 100
# Out:
# 0       278.0
# 1       269.0
# 2       248.0
# 3       264.0
# 4         NaN
#         ...
# 4911    187.0
# 4912    143.0
# 4913    176.0
# 4914    200.0
# 4915    190.0
# Name: duration, Length: 4916, dtype: float64

# %%
# setting indices
movie2_df = movie_df.set_index('movie_title')
movie2_df.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
# When you read the csv file, you can directly set the indices from one of columns!
movie2_df = pd.read_csv('data/movie.csv', index_col='movie_title')
movie2_df.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
# resetting the indices
    # when you reset the indices, the original index column moves to the 1st column. (Be careful!)
    # BUT, if you don't need the original index column anymore, you can write 'drop=True'!
movie3_df = movie2_df.reset_index()
movie3_df.head()
# Out:
#                                   movie_title  color      director_name  \
# 0                                      Avatar  Color      James Cameron
# 1    Pirates of the Caribbean: At World's End  Color     Gore Verbinski
# 2                                     Spectre  Color         Sam Mendes
# 3                       The Dark Knight Rises  Color  Christopher Nolan
# 4  Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
# 2                   602.0     148.0                      0.0
# 3                   813.0     164.0                  22000.0
# 4                     NaN       NaN                    131.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# ...

# %%
# WOW!!!!! It's magic!
movie_df.dropna().reset_index(drop=True)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 3650  Color    Olivier Assayas                    81.0     110.0
# 3651  Color       Jafar Panahi                    64.0      90.0
# 3652  Color      Shane Carruth                   143.0      77.0
# 3653  Color   Robert Rodriguez                    56.0      81.0
# 3654  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
# Renaming the indices and column titles!
movie_df.rename(index={0:'Avatar'}, columns={'color':'COLOUR', 'director_name':'DIRECTOR_NANE', 'duration':'LENGTH'})
# Out:
#        COLOUR      DIRECTOR_NANE  num_critic_for_reviews  LENGTH  \
# Avatar  Color      James Cameron                   723.0   178.0
# 1       Color     Gore Verbinski                   302.0   169.0
# 2       Color         Sam Mendes                   602.0   148.0
# 3       Color  Christopher Nolan                   813.0   164.0
# 4         NaN        Doug Walker                     NaN     NaN
# ...       ...                ...                     ...     ...
# 4911    Color        Scott Smith                     1.0    87.0
# 4912    Color                NaN                    43.0    43.0
# 4913    Color   Benjamin Roberds                    13.0    76.0
# 4914    Color        Daniel Hsia                    14.0   100.0
# 4915    Color           Jon Gunn                    43.0    90.0
#
#         director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# Avatar                      0.0                   855.0  Joel David Moore
# ...

# %%
# renaming with this independent dict will be more convenient!
columns_dict = {'color':'COL', 'director_name':'DIRECTOR', 'duration':'DUR'}
movie_renamed = movie_df.rename(columns=columns_dict)
movie_renamed.head()
# Out:
#      COL           DIRECTOR  num_critic_for_reviews    DUR  \
# 0  Color      James Cameron                   723.0  178.0
# 1  Color     Gore Verbinski                   302.0  169.0
# 2  Color         Sam Mendes                   602.0  148.0
# 3  Color  Christopher Nolan                   813.0  164.0
# 4    NaN        Doug Walker                     NaN    NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
# renaming with this list will be also more convenient as well!
columns_list = movie_df.columns.to_list()
columns_list[0] = 'COLOR'
columns_list[1] = 'DIRECTOR'
columns_list[3] = 'DURATION'
movie_df.columns = columns_list
movie_df.head()
# Out:
#    COLOR           DIRECTOR  num_critic_for_reviews  DURATION  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie_df.drop(range(0,10,1), axis='index')
# Out:
#       COLOR          DIRECTOR  num_critic_for_reviews  DURATION  \
# 10    Color       Zack Snyder                   673.0     183.0
# 11    Color      Bryan Singer                   434.0     169.0
# 12    Color      Marc Forster                   403.0     106.0
# 13    Color    Gore Verbinski                   313.0     151.0
# 14    Color    Gore Verbinski                   450.0     150.0
# ...     ...               ...                     ...       ...
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 10                        0.0                  2000.0      Lauren Cohan
# ...

# %%
# delete some columns
movie_df.drop(['gross', 'DURATION'], axis='columns')
# movie_df.drop(columns=['gross', 'DURATION']) is also the same
# Out:
#       COLOR           DIRECTOR  num_critic_for_reviews  \
# 0     Color      James Cameron                   723.0
# 1     Color     Gore Verbinski                   302.0
# 2     Color         Sam Mendes                   602.0
# 3     Color  Christopher Nolan                   813.0
# 4       NaN        Doug Walker                     NaN
# ...     ...                ...                     ...
# 4911  Color        Scott Smith                     1.0
# 4912  Color                NaN                    43.0
# 4913  Color   Benjamin Roberds                    13.0
# 4914  Color        Daniel Hsia                    14.0
# 4915  Color           Jon Gunn                    43.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# ...

# %%
# add columns
movie_df['Joshua'] = 'Happy'
movie_df.head()
# Out:
#    COLOR           DIRECTOR  num_critic_for_reviews  DURATION  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie_df['Revenue per Bedbet'] = movie_df['COLOR'] + '==' + movie_df['DIRECTOR']
movie_df.head()
# Out:
#    COLOR           DIRECTOR  num_critic_for_reviews  DURATION  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...
